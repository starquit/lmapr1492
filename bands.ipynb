# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.electronic_structure.bandstructure import BandStructure
from pymatgen.electronic_structure.plotter import BSPlotter

with MPRester("c5FIVeAZuDMNrwBx") as m:
    band_s = m.get_bandstructure_by_material_id("mp-29868") #je cree ma structure de bande
    band_s_plot = BSPlotter(band_s) #je crée un objet BSPlotter pour faciliter la prise de données de ma structure de bande
    #print(band_s_plot.get_plot()) 
    datas = band_s_plot.bs_plot_data() #datas = mes données 
    print("La bande interdite :")
    print(datas.get('band_gap'), "eV")
    print("=====================================================")
    #print(datas) #à activer si on veut voir les donnéees de la structure de bandes
    print(" ")
    print("Direction dans laquelle la première bande de conduction présente le moins de dispersion : A/L-M/K avec une pente de 0.21168532907420268")
    print("Direction dans laquelle la première bande de conduction  présente le plus de dispersion : K-Gamma avec une pente de 0.8340684946951062  ")
    print(" ")
    print("Direction dans laquelle la dernière bande de valence présente le moins de dispersion : Gamma-A avec une pente de 0.395395608388915 ")
    print("Direction dans laquelle la dernière bande de valence présente le plus de dispersion : A-L avec une pente de  16.1702668360864 ")
    print(" ")
    print("Comment trouver ces valeurs et aboutir à ces réponses? Voici la méthode que j'ai utilisé :")
    print("=============================================================================================")
    
    print("Pour connaître les dispersions, il faut calculer les pentes de chaque bande : dy/dx")
    print("Le dx sera : la différence entre les énergies")
    print("Le dy sera : la différence entre les distances, soit la longueur")
    print(" ")
    
    print("On va print les distances :")
    print("=====================================================")
    print("Gamma-M : ", ((datas.get('ticks')).get('distance'))[1]-((datas.get('ticks')).get('distance'))[0])
    print("M-K : ", ((datas.get('ticks')).get('distance'))[3]-((datas.get('ticks')).get('distance'))[2])
    print("K-Gamma : ", ((datas.get('ticks')).get('distance'))[5]-((datas.get('ticks')).get('distance'))[4])
    print("Gamma-A : ", ((datas.get('ticks')).get('distance'))[7]-((datas.get('ticks')).get('distance'))[6])
    print("A-L : ", ((datas.get('ticks')).get('distance'))[9]-((datas.get('ticks')).get('distance'))[8])
    print("L-H : ", ((datas.get('ticks')).get('distance'))[11]-((datas.get('ticks')).get('distance'))[10])
    print("H-A/L : ", ((datas.get('ticks')).get('distance'))[13]-((datas.get('ticks')).get('distance'))[12])
    print("A/L-M/K: ", ((datas.get('ticks')).get('distance'))[14]-((datas.get('ticks')).get('distance'))[13])
    print("M/K-H : ", ((datas.get('ticks')).get('distance'))[15]-((datas.get('ticks')).get('distance'))[14])


    print(" ")   
    print("Nos valeurs d'énergies nous seront données en appelant la fonction datas.get('energy'), exemple ci-dessous")   
    print("ex : pour la dernière bande de conduction on a dans la direction Gamma-M")  
    print(((datas.get('energy')[0]).get('1')[11]))       
    print("=====================================================")
    
    print(" ")
    print("Nous pouvons maintenant calculer nos dx, pour ")
    print("A. Dernière bande de conduction :")
    
    print("=====================================================")
    
    
    print("Gamma-M : ",((datas.get('energy')[0]).get('1')[11])[19]-((datas.get('energy')[0]).get('1')[11])[0])
    print("M-K : ",((datas.get('energy')[1]).get('1')[11])[11]-((datas.get('energy')[1]).get('1')[11])[0])
    print("K-Gamma : ", ((datas.get('energy')[2]).get('1')[11])[22]-((datas.get('energy')[2]).get('1')[11])[0])
    print("Gamma-A : ", ((datas.get('energy')[3]).get('1')[11])[12]-((datas.get('energy')[3]).get('1')[11])[0])
    print("A-L : ", ((datas.get('energy')[4]).get('1')[11])[19]-((datas.get('energy')[4]).get('1')[11])[0])
    print("L-H : ", ((datas.get('energy')[5]).get('1')[11])[11]-((datas.get('energy')[5]).get('1')[11])[0])
    print("H-A/L : ", ((datas.get('energy')[6]).get('1')[11])[22]-((datas.get('energy')[6]).get('1')[11])[0])
    print("A/L-M/K : ", ((datas.get('energy')[7]).get('1')[11])[12]-((datas.get('energy')[7]).get('1')[11])[0])
    print("M/K-H : ", ((datas.get('energy')[8]).get('1')[11])[12]-((datas.get('energy')[1]).get('1')[11])[0])
    
    print(" ")
    
    print("B. Dernière bande de valence : ")
    
    print("=====================================================")
    
    print("Gamma-M : ",((datas.get('energy')[0]).get('1')[10])[19]-((datas.get('energy')[0]).get('1')[10])[0])
    print("M-K : ",((datas.get('energy')[1]).get('1')[10])[11]-((datas.get('energy')[1]).get('1')[10])[0])
    print("K-Gamma : ", ((datas.get('energy')[2]).get('1')[10])[22]-((datas.get('energy')[2]).get('1')[10])[0])
    print("Gamma-A : ", ((datas.get('energy')[3]).get('1')[10])[12]-((datas.get('energy')[3]).get('1')[10])[0])
    print("A-L : ", ((datas.get('energy')[4]).get('1')[10])[19]-((datas.get('energy')[4]).get('1')[10])[0])
    print("L-H : ", ((datas.get('energy')[5]).get('1')[10])[11]-((datas.get('energy')[5]).get('1')[10])[0])
    print("H-A/L : ", ((datas.get('energy')[6]).get('1')[10])[22]-((datas.get('energy')[6]).get('1')[10])[0])
    print("A/L-M/K : ", ((datas.get('energy')[7]).get('1')[10])[12]-((datas.get('energy')[7]).get('1')[10])[0])
    print("M/K-H : ", ((datas.get('energy')[8]).get('1')[10])[12]-((datas.get('energy')[1]).get('1')[10])[0])

    
    print(" ")
    print("Il nous reste à calculer les pentes dans chaque direction ")
    print("A. Pour la première bande de conduction")
    print("=====================================================")
    print("Gamma-M : ", (((datas.get('ticks')).get('distance'))[1]-((datas.get('ticks')).get('distance'))[0])/(((datas.get('energy')[0]).get('1')[11])[19]-((datas.get('energy')[0]).get('1')[11])[0]))
    print("M-K : ",(((datas.get('ticks')).get('distance'))[3]-((datas.get('ticks')).get('distance'))[2])/(((datas.get('energy')[1]).get('1')[11])[11]-((datas.get('energy')[1]).get('1')[11])[0]))
    print("K-Gamma : ", (((datas.get('ticks')).get('distance'))[5]-((datas.get('ticks')).get('distance'))[4])/(((datas.get('energy')[2]).get('1')[11])[22]-((datas.get('energy')[2]).get('1')[11])[0]))
    print("Gamma-A : ", (((datas.get('ticks')).get('distance'))[7]-((datas.get('ticks')).get('distance'))[6])/(((datas.get('energy')[3]).get('1')[11])[12]-((datas.get('energy')[3]).get('1')[11])[0]))
    print("A-L : ",(((datas.get('energy')[4]).get('1')[11])[19]-((datas.get('energy')[4]).get('1')[11])[0])/(((datas.get('energy')[4]).get('1')[11])[19]-((datas.get('energy')[4]).get('1')[11])[0]))
    print("L-H : ",(((datas.get('ticks')).get('distance'))[11]-((datas.get('ticks')).get('distance'))[10])/(((datas.get('energy')[5]).get('1')[11])[11]-((datas.get('energy')[5]).get('1')[11])[0]))
    print("H-A/L : ",(((datas.get('ticks')).get('distance'))[13]-((datas.get('ticks')).get('distance'))[12])/(((datas.get('energy')[6]).get('1')[11])[22]-((datas.get('energy')[6]).get('1')[11])[0]))
    print("A/L-M/K : ",(((datas.get('ticks')).get('distance'))[14]-((datas.get('ticks')).get('distance'))[13])/(((datas.get('energy')[7]).get('1')[11])[12]-((datas.get('energy')[7]).get('1')[11])[0]))
    print("M/K-H : ",(((datas.get('ticks')).get('distance'))[15]-((datas.get('ticks')).get('distance'))[14])/(((datas.get('energy')[8]).get('1')[11])[12]-((datas.get('energy')[1]).get('1')[11])[0]))
    
    print(" ")
    print("A. Pour la dernière bande de valence")
    print("=====================================================")
    print("Gamma-M : ", (((datas.get('ticks')).get('distance'))[1]-((datas.get('ticks')).get('distance'))[0])/(((datas.get('energy')[0]).get('1')[10])[19]-((datas.get('energy')[0]).get('1')[10])[0]))
    print("M-K : ",(((datas.get('ticks')).get('distance'))[3]-((datas.get('ticks')).get('distance'))[2])/(((datas.get('energy')[1]).get('1')[10])[11]-((datas.get('energy')[1]).get('1')[10])[0]))
    print("K-Gamma : ", (((datas.get('ticks')).get('distance'))[5]-((datas.get('ticks')).get('distance'))[4])/(((datas.get('energy')[2]).get('1')[10])[22]-((datas.get('energy')[2]).get('1')[10])[0]))
    print("Gamma-A : ", (((datas.get('ticks')).get('distance'))[7]-((datas.get('ticks')).get('distance'))[6])/(((datas.get('energy')[3]).get('1')[10])[12]-((datas.get('energy')[3]).get('1')[10])[0]))
    print("A-L : ",(((datas.get('energy')[4]).get('1')[11])[19]-((datas.get('energy')[4]).get('1')[11])[0])/(((datas.get('energy')[4]).get('1')[10])[19]-((datas.get('energy')[4]).get('1')[10])[0]))
    print("L-H : ",(((datas.get('ticks')).get('distance'))[11]-((datas.get('ticks')).get('distance'))[10])/(((datas.get('energy')[5]).get('1')[10])[11]-((datas.get('energy')[5]).get('1')[10])[0]))
    print("H-A/L : ",(((datas.get('ticks')).get('distance'))[13]-((datas.get('ticks')).get('distance'))[12])/(((datas.get('energy')[6]).get('1')[10])[22]-((datas.get('energy')[6]).get('1')[10])[0]))
    print("A/L-M/K : ",(((datas.get('ticks')).get('distance'))[14]-((datas.get('ticks')).get('distance'))[13])/(((datas.get('energy')[7]).get('1')[10])[12]-((datas.get('energy')[7]).get('1')[10])[0]))
    print("M/K-H : ",(((datas.get('ticks')).get('distance'))[15]-((datas.get('ticks')).get('distance'))[14])/(((datas.get('energy')[8]).get('1')[10])[12]-((datas.get('energy')[1]).get('1')[10])[0]))
# Out:
# La bande interdite :
# Indirect A-L bandgap = 1.5321 eV
# ...
#
# Direction dans laquelle la première bande de conduction présente le moins de dispersion : A/L-M/K avec une pente de 0.21168532907420268
# Direction dans laquelle la première bande de conduction  présente le plus de dispersion : K-Gamma avec une pente de 0.8340684946951062
#
# Direction dans laquelle la dernière bande de valence présente le moins de dispersion : Gamma-A avec une pente de 0.395395608388915
# Direction dans laquelle la dernière bande de valence présente le plus de dispersion : A-L avec une pente de  16.1702668360864
#
# Comment trouver ces valeurs et aboutir à ces réponses? Voici la méthode que j'ai utilisé :
# ...
# Pour connaître les dispersions, il faut calculer les pentes de chaque bande : dy/dx
# Le dx sera : la différence entre les énergies
# Le dy sera : la différence entre les distances, soit la longueur
#
# On va print les distances :
# ...
# Gamma-M :  0.9378661401047166
# M-K :  0.5414772556034457
# ...
