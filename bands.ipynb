# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.electronic_structure.bandstructure import BandStructure
from pymatgen.electronic_structure.plotter import BSPlotter


with MPRester("c5FIVeAZuDMNrwBx") as m:
    band_s = m.get_bandstructure_by_material_id("mp-29868") #je crée ma structure de bande
    band_s_plot = BSPlotter(band_s) #je crée un objet BSPlotter pour faciliter la prise de données de ma structure de bande
    #print(band_s_plot.get_plot()) #à activer si on veut afficher la structure de bande
    datas = band_s_plot.bs_plot_data() #datas = mes données 
    print("La bande interdite :")
    print(datas.get('band_gap'), "eV")
    print("=====================================================")
    #print(datas) #à activer si on veut voir les donnéees de la structure de bandes
    print(" ")
    print("Direction dans laquelle la première bande de conduction présente le moins de dispersion : A-L avec une pente de 1.0")
    print("Direction dans laquelle la première bande de conduction  présente le plus de dispersion :  A/L-M/K avec une pente de 4.723992939772728 ")
    print(" ")
    print("Direction dans laquelle la dernière bande de valence présente le moins de dispersion : L-H avec une pente de 0.18800420321727035 ") #le signe - car importera peu ici la croissance/décroissance de la pente ne sera pas importante seule sa valeur l'est 
    print("Direction dans laquelle la dernière bande de valence présente le plus de dispersion : A-L avec une pente de 3.3973827363686557 ")
    print(" ")
    print("Ces directions sont indiquées dans l'image à l'output 120 : en vert les minima de dispersions et en rouge les maxima de dispersion")
    print(" ")
    print("Comment trouver ces valeurs et aboutir à ces réponses? Voici la méthode que j'ai utilisé :")
    print("=============================================================================================")
    
    print("Pour connaître les dispersions, il faut calculer les pentes des bandes dans chaque direction : dy/dx")
    print("Le dx sera : la différence entre les distances, soit la longueur")
    print("Le dy sera : la différence entre les énergies")
    print(" ")
    
    print("On calcule les distances :")
    print("==============================")
    print("Gamma-M : ", ((datas.get('ticks')).get('distance'))[1]-((datas.get('ticks')).get('distance'))[0])
    print("M-K : ", ((datas.get('ticks')).get('distance'))[3]-((datas.get('ticks')).get('distance'))[2])
    print("K-Gamma : ", ((datas.get('ticks')).get('distance'))[5]-((datas.get('ticks')).get('distance'))[4])
    print("Gamma-A : ", ((datas.get('ticks')).get('distance'))[7]-((datas.get('ticks')).get('distance'))[6])
    print("A-L : ", ((datas.get('ticks')).get('distance'))[9]-((datas.get('ticks')).get('distance'))[8])
    print("L-H : ", ((datas.get('ticks')).get('distance'))[11]-((datas.get('ticks')).get('distance'))[10])
    print("H-A/L : ", ((datas.get('ticks')).get('distance'))[13]-((datas.get('ticks')).get('distance'))[12])
    print("A/L-M/K: ", ((datas.get('ticks')).get('distance'))[14]-((datas.get('ticks')).get('distance'))[13])
    print("M/K-H : ", ((datas.get('ticks')).get('distance'))[15]-((datas.get('ticks')).get('distance'))[14])


    print(" ")   
    print("Nos valeurs d'énergies nous seront données en appelant la fonction datas.get('energy'), exemple ci-dessous")   
    print("ex : pour la dernière bande de conduction on a dans la direction Gamma-M :")  
    print(((datas.get('energy')[0]).get('1')[11]))       
    print("=============================================================================================================")
    
    print(" ")
    print("Nous pouvons maintenant calculer nos dy, pour ")
    print("A. Première bande de conduction :")
    
    print("=====================================================")
    
    
    print("Gamma-M : ",((datas.get('energy')[0]).get('1')[11])[19]-((datas.get('energy')[0]).get('1')[11])[0])
    print("M-K : ",((datas.get('energy')[1]).get('1')[11])[11]-((datas.get('energy')[1]).get('1')[11])[0])
    print("K-Gamma : ", ((datas.get('energy')[2]).get('1')[11])[22]-((datas.get('energy')[2]).get('1')[11])[0])
    print("Gamma-A : ", ((datas.get('energy')[3]).get('1')[11])[12]-((datas.get('energy')[3]).get('1')[11])[0])
    print("A-L : ", ((datas.get('energy')[4]).get('1')[11])[19]-((datas.get('energy')[4]).get('1')[11])[0])
    print("L-H : ", ((datas.get('energy')[5]).get('1')[11])[11]-((datas.get('energy')[5]).get('1')[11])[0])
    print("H-A/L : ", ((datas.get('energy')[6]).get('1')[11])[22]-((datas.get('energy')[6]).get('1')[11])[0])
    print("A/L-M/K : ", ((datas.get('energy')[7]).get('1')[11])[12]-((datas.get('energy')[7]).get('1')[11])[0])
    print("M/K-H : ", ((datas.get('energy')[8]).get('1')[11])[12]-((datas.get('energy')[1]).get('1')[11])[0])
    
    print(" ")
    
    print("B. Dernière bande de valence : ")
    
    print("==================================")
    
    print("Gamma-M : ",((datas.get('energy')[0]).get('1')[10])[19]-((datas.get('energy')[0]).get('1')[10])[0])
    print("M-K : ",((datas.get('energy')[1]).get('1')[10])[11]-((datas.get('energy')[1]).get('1')[10])[0])
    print("K-Gamma : ", ((datas.get('energy')[2]).get('1')[10])[22]-((datas.get('energy')[2]).get('1')[10])[0])
    print("Gamma-A : ", ((datas.get('energy')[3]).get('1')[10])[12]-((datas.get('energy')[3]).get('1')[10])[0])
    print("A-L : ", ((datas.get('energy')[4]).get('1')[10])[19]-((datas.get('energy')[4]).get('1')[10])[0])
    print("L-H : ", ((datas.get('energy')[5]).get('1')[10])[11]-((datas.get('energy')[5]).get('1')[10])[0])
    print("H-A/L : ", ((datas.get('energy')[6]).get('1')[10])[22]-((datas.get('energy')[6]).get('1')[10])[0])
    print("A/L-M/K : ", ((datas.get('energy')[7]).get('1')[10])[12]-((datas.get('energy')[7]).get('1')[10])[0])
    print("M/K-H : ", ((datas.get('energy')[8]).get('1')[10])[12]-((datas.get('energy')[1]).get('1')[10])[0])

    
    print(" ")
    print("Il nous reste à calculer les pentes dans chaque direction ")
    print("A. Pour la première bande de conduction")
    print("===========================================")
    print("Gamma-M : ", (((datas.get('energy')[0]).get('1')[11])[19]-((datas.get('energy')[0]).get('1')[11])[0])/(((datas.get('ticks')).get('distance'))[1]-((datas.get('ticks')).get('distance'))[0]))
    print("M-K : ",(((datas.get('energy')[1]).get('1')[11])[11]-((datas.get('energy')[1]).get('1')[11])[0])/(((datas.get('ticks')).get('distance'))[3]-((datas.get('ticks')).get('distance'))[2]))
    print("K-Gamma : ",(((datas.get('energy')[2]).get('1')[11])[22]-((datas.get('energy')[2]).get('1')[11])[0])/(((datas.get('ticks')).get('distance'))[5]-((datas.get('ticks')).get('distance'))[4]))
    print("Gamma-A : ", (((datas.get('energy')[3]).get('1')[11])[12]-((datas.get('energy')[3]).get('1')[11])[0])/(((datas.get('ticks')).get('distance'))[7]-((datas.get('ticks')).get('distance'))[6]))
    print("A-L : ",(((datas.get('energy')[4]).get('1')[11])[19]-((datas.get('energy')[4]).get('1')[11])[0])/(((datas.get('energy')[4]).get('1')[11])[19]-((datas.get('energy')[4]).get('1')[11])[0]))
    print("L-H : ",(((datas.get('energy')[5]).get('1')[11])[11]-((datas.get('energy')[5]).get('1')[11])[0])/(((datas.get('ticks')).get('distance'))[11]-((datas.get('ticks')).get('distance'))[10]))
    print("H-A/L : ",(((datas.get('energy')[6]).get('1')[11])[22]-((datas.get('energy')[6]).get('1')[11])[0])/(((datas.get('ticks')).get('distance'))[13]-((datas.get('ticks')).get('distance'))[12]))
    print("A/L-M/K : ",(((datas.get('energy')[7]).get('1')[11])[12]-((datas.get('energy')[7]).get('1')[11])[0])/(((datas.get('ticks')).get('distance'))[14]-((datas.get('ticks')).get('distance'))[13]))
    print("M/K-H : ",(((datas.get('energy')[8]).get('1')[11])[12]-((datas.get('energy')[1]).get('1')[11])[0])/(((datas.get('ticks')).get('distance'))[15]-((datas.get('ticks')).get('distance'))[14]))
    
    print(" ")
    print("A. Pour la dernière bande de valence")
    print("===========================================")
    print("Gamma-M : ",(((datas.get('energy')[0]).get('1')[10])[19]-((datas.get('energy')[0]).get('1')[10])[0])/(((datas.get('ticks')).get('distance'))[1]-((datas.get('ticks')).get('distance'))[0]))
    print("M-K : ",(((datas.get('energy')[1]).get('1')[10])[11]-((datas.get('energy')[1]).get('1')[10])[0])/(((datas.get('ticks')).get('distance'))[3]-((datas.get('ticks')).get('distance'))[2]))
    print("K-Gamma : ", (((datas.get('energy')[2]).get('1')[10])[22]-((datas.get('energy')[2]).get('1')[10])[0])/(((datas.get('ticks')).get('distance'))[5]-((datas.get('ticks')).get('distance'))[4]))
    print("Gamma-A : ", (((datas.get('energy')[3]).get('1')[10])[12]-((datas.get('energy')[3]).get('1')[10])[0])/(((datas.get('ticks')).get('distance'))[7]-((datas.get('ticks')).get('distance'))[6]))
    print("A-L : ",((datas.get('energy')[4]).get('1')[10])[19]-((datas.get('energy')[4]).get('1')[10])[0]/((datas.get('ticks')).get('distance'))[9]-((datas.get('ticks')).get('distance'))[8])
    print("L-H : ",(((datas.get('energy')[5]).get('1')[10])[11]-((datas.get('energy')[5]).get('1')[10])[0])/(((datas.get('ticks')).get('distance'))[11]-((datas.get('ticks')).get('distance'))[10]))
    print("H-A/L : ",(((datas.get('energy')[6]).get('1')[10])[22]-((datas.get('energy')[6]).get('1')[10])[0])/(((datas.get('ticks')).get('distance'))[13]-((datas.get('ticks')).get('distance'))[12]))
    print("A/L-M/K : ",(((datas.get('energy')[7]).get('1')[10])[12]-((datas.get('energy')[7]).get('1')[10])[0])/(((datas.get('ticks')).get('distance'))[14]-((datas.get('ticks')).get('distance'))[13]))
    print("M/K-H : ",(((datas.get('energy')[8]).get('1')[10])[12]-((datas.get('energy')[1]).get('1')[10])[0])/(((datas.get('ticks')).get('distance'))[15]-((datas.get('ticks')).get('distance'))[14]))
    
    print(" ")
    print("La formule de la masse effective est affichée dans la prochaine commande, output 96") #source Wikipédia
    print(" ")
    print("La masse effective en supposant une dispertion parabolique : ")
    print(" ")
    print("A. Au sommet de la dernière bande de valence")
    print("=================================================")
    print("Tentons de définir la fonction du second degré de l'énergie, pour ça on prend : ")
    print("Les coordonnées du sommet de la parabole et d'un point par lequel elle passe,")
    print("Pour rappel, l'équation d'une parabole peut se noter : a(x-abscisse du sommet)^2 +ordonnée du sommet = f(x)")
    print("Au sommet : ",(datas.get('vbm')[0]))
    print("En choisissant le point d'énergie -1.515 dans la direction Gamma, la distance est de : ", ((datas.get('ticks')).get('distance'))[6], "donc, nous avons")
    print("En ce point : (",((datas.get('ticks')).get('distance'))[6], ", -1.515)")
    print("Ce qui nous permet d'obtenir l'équation du second degré suivante : E(k) = -4.223 (x-3.161)^2")
    print(" ")
    print("La dérivée seconde de cette fonction est une constante : -8.446")
    print("Multipliée par 1/hbar^2 on a : 1/m = -8.446/(1.055*10^-34)^2 = -7.594*10^68")
    print("La masse effective = -1.316*10^-69 kg")
    print(" ")
    
    print("B. A la base de la première bande de conduction")
    print("=====================================================")
    print("Nous utiliserons exactement la même méthode que pour le point A.")
    print("Au sommet : ",(datas.get('cbm'))[1])
    print("En choisissant le point d'énergie 2.436 dans la direction H, la distance est de : ", ((datas.get('ticks')).get('distance'))[11], "donc, nous avons")
    print("En ce point : (",((datas.get('ticks')).get('distance'))[11], ", 2.436)")
    print("Ce qui nous permet d'obtenir l'équation du second degré suivante : E(k) = 1.334 (x-4.640)^2 + 1.5321")
    print(" ")
    print("La dérivée seconde de cette fonction est une constante : 2.669")
    print("Multipliée par 1/hbar^2 on a : 1/m = -8.446/(1.055*10^-34)^2 = 2.397*10^68")
    print("La masse effective = 4.17*10^-69 kg")
    print(" ")
# Out:
# La bande interdite :
# Indirect A-L bandgap = 1.5321 eV
# ...
#
# Direction dans laquelle la première bande de conduction présente le moins de dispersion : A-L avec une pente de 1.0
# Direction dans laquelle la première bande de conduction  présente le plus de dispersion :  A/L-M/K avec une pente de 4.723992939772728
#
# Direction dans laquelle la dernière bande de valence présente le moins de dispersion : L-H avec une pente de 0.18800420321727035
# Direction dans laquelle la dernière bande de valence présente le plus de dispersion : A-L avec une pente de 3.3973827363686557
#
# Ces directions sont indiquées dans l'image à l'output 120 : en vert les minima de dispersions et en rouge les maxima de dispersion
#
# Comment trouver ces valeurs et aboutir à ces réponses? Voici la méthode que j'ai utilisé :
# ...
# Pour connaître les dispersions, il faut calculer les pentes des bandes dans chaque direction : dy/dx
# Le dx sera : la différence entre les distances, soit la longueur
# ...

# %%
from IPython.display import Image
print("Formule de la masse effective selon Wikipédia")
Image(filename='formule.png')

# %%
from IPython.display import Image
print("Indication des directions de minima (en vert) et maxima (en rouge) de dispersion pour les bandes demandées")
Image(filename='BS.png')
# Out:
# Indication des directions de minima (en vert) et maxima (en rouge) de dispersion pour les bandes demandées
